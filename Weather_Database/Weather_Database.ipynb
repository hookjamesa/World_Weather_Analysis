# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | nazare
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | traverse city
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | kavaratti
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | changji
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | penzance
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | buritizeiro
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | qaqortoq
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | tiznit
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | inhambane
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | gizo
# Processing Record 40 of Set 1 | inirida
# Processing Record 41 of Set 1 | berlevag
# Processing Record 42 of Set 1 | tarakan
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | casper
# Processing Record 45 of Set 1 | dawlatabad
# Processing Record 46 of Set 1 | adrar
# Processing Record 47 of Set 1 | verkhnevilyuysk
# Processing Record 48 of Set 1 | turtas
# Processing Record 49 of Set 1 | mogadishu
# Processing Record 50 of Set 1 | dawei
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | barra patuca
# Processing Record 6 of Set 2 | havelock
# Processing Record 7 of Set 2 | constitucion
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | tombouctou
# Processing Record 11 of Set 2 | los llanos de aridane
# Processing Record 12 of Set 2 | taoudenni
# Processing Record 13 of Set 2 | ituporanga
# Processing Record 14 of Set 2 | tual
# Processing Record 15 of Set 2 | banjar
# Processing Record 16 of Set 2 | adolfo ruiz cortines
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | francia
# Processing Record 20 of Set 2 | santa rosa
# Processing Record 21 of Set 2 | houston
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | phrai bung
# City not found. Skipping...
# Processing Record 24 of Set 2 | orange cove
# Processing Record 25 of Set 2 | huangnihe
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | jasper
# Processing Record 28 of Set 2 | vangaindrano
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | lodja
# Processing Record 31 of Set 2 | aasiaat
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | almazar
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | kalabo
# Processing Record 37 of Set 2 | luoyang
# Processing Record 38 of Set 2 | pospelikha
# Processing Record 39 of Set 2 | tongling
# Processing Record 40 of Set 2 | erzin
# Processing Record 41 of Set 2 | ochakiv
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | kidal
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | batonyterenye
# Processing Record 48 of Set 2 | cibitoke
# Processing Record 49 of Set 2 | raudeberg
# Processing Record 50 of Set 2 | sistranda
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | gimli
# Processing Record 3 of Set 3 | tiarei
# Processing Record 4 of Set 3 | saint-pierre
# Processing Record 5 of Set 3 | skjervoy
# Processing Record 6 of Set 3 | kamaishi
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 3 | hirschaid
# Processing Record 11 of Set 3 | khalkhal
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | half moon bay
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | shache
# Processing Record 17 of Set 3 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | baykit
# Processing Record 21 of Set 3 | naugarzan
# City not found. Skipping...
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | north myrtle beach
# Processing Record 24 of Set 3 | yerbogachen
# Processing Record 25 of Set 3 | phuthaditjhaba
# Processing Record 26 of Set 3 | sambava
# Processing Record 27 of Set 3 | san-pedro
# Processing Record 28 of Set 3 | takoradi
# Processing Record 29 of Set 3 | swan hill
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | morant bay
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | middelburg
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | maumere
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | westport
# Processing Record 41 of Set 3 | zwedru
# Processing Record 42 of Set 3 | amga
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | jinchang
# Processing Record 45 of Set 3 | ola
# Processing Record 46 of Set 3 | biltine
# Processing Record 47 of Set 3 | shetpe
# Processing Record 48 of Set 3 | ramnagar
# Processing Record 49 of Set 3 | florencia
# Processing Record 50 of Set 3 | carballo
# Processing Record 1 of Set 4 | shebunino
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | makurdi
# Processing Record 6 of Set 4 | yenagoa
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | burica
# City not found. Skipping...
# Processing Record 9 of Set 4 | de-kastri
# Processing Record 10 of Set 4 | tukrah
# Processing Record 11 of Set 4 | mahibadhoo
# Processing Record 12 of Set 4 | yelizovo
# Processing Record 13 of Set 4 | chandler
# Processing Record 14 of Set 4 | jalu
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | kindu
# Processing Record 17 of Set 4 | olafsvik
# Processing Record 18 of Set 4 | watertown
# Processing Record 19 of Set 4 | petrozavodsk
# Processing Record 20 of Set 4 | karimganj
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | roma
# Processing Record 23 of Set 4 | kampong thum
# Processing Record 24 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | una
# Processing Record 30 of Set 4 | gazanjyk
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | harper
# Processing Record 33 of Set 4 | save
# Processing Record 34 of Set 4 | kirakira
# Processing Record 35 of Set 4 | caranavi
# Processing Record 36 of Set 4 | eenhana
# Processing Record 37 of Set 4 | seoul
# Processing Record 38 of Set 4 | matara
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | merrill
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | kieta
# Processing Record 43 of Set 4 | port hawkesbury
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | borujerd
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | wanning
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | cidreira
# Processing Record 50 of Set 4 | pisco
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | butaritari
# Processing Record 3 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 5 | biak
# Processing Record 5 of Set 5 | hongan
# City not found. Skipping...
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | zhenlai
# Processing Record 8 of Set 5 | mount gambier
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | havre-saint-pierre
# Processing Record 11 of Set 5 | fossombrone
# Processing Record 12 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 13 of Set 5 | tazmalt
# Processing Record 14 of Set 5 | vila velha
# Processing Record 15 of Set 5 | barra do bugres
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | campbellsville
# Processing Record 18 of Set 5 | henties bay
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | atikokan
# Processing Record 21 of Set 5 | ippy
# Processing Record 22 of Set 5 | dikson
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | mindelo
# Processing Record 26 of Set 5 | abay
# Processing Record 27 of Set 5 | taylor
# Processing Record 28 of Set 5 | lismore
# Processing Record 29 of Set 5 | noumea
# Processing Record 30 of Set 5 | padang
# Processing Record 31 of Set 5 | iracoubo
# Processing Record 32 of Set 5 | sijunjung
# Processing Record 33 of Set 5 | yulara
# Processing Record 34 of Set 5 | vao
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | gangarampur
# Processing Record 37 of Set 5 | broome
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | ust-tsilma
# Processing Record 40 of Set 5 | okhotsk
# Processing Record 41 of Set 5 | dakar
# Processing Record 42 of Set 5 | pevek
# Processing Record 43 of Set 5 | sampit
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | semey
# Processing Record 46 of Set 5 | serebryansk
# Processing Record 47 of Set 5 | alta floresta
# Processing Record 48 of Set 5 | at-bashi
# Processing Record 49 of Set 5 | kaitangata
# Processing Record 50 of Set 5 | cabo san lucas
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | ngama
# Processing Record 3 of Set 6 | gorodets
# Processing Record 4 of Set 6 | nicolas bravo
# Processing Record 5 of Set 6 | tromso
# Processing Record 6 of Set 6 | nador
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | arraial do cabo
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | tias
# Processing Record 13 of Set 6 | shelburne
# Processing Record 14 of Set 6 | sereflikochisar
# Processing Record 15 of Set 6 | kiruna
# Processing Record 16 of Set 6 | mahajanga
# Processing Record 17 of Set 6 | bay-khaak
# Processing Record 18 of Set 6 | bambanglipuro
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 6 | lumeje
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | metro
# Processing Record 24 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 6 | san carlos de bariloche
# Processing Record 26 of Set 6 | anloga
# Processing Record 27 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 28 of Set 6 | praia
# Processing Record 29 of Set 6 | wolgast
# Processing Record 30 of Set 6 | betsiamites
# Processing Record 31 of Set 6 | jacareacanga
# Processing Record 32 of Set 6 | sao jose da coroa grande
# Processing Record 33 of Set 6 | yorkton
# Processing Record 34 of Set 6 | espirito santo do pinhal
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | garowe
# Processing Record 37 of Set 6 | puerto escondido
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 40 of Set 6 | iquitos
# Processing Record 41 of Set 6 | upernavik
# Processing Record 42 of Set 6 | ferrol
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | scarborough
# Processing Record 45 of Set 6 | chulman
# Processing Record 46 of Set 6 | valparaiso
# Processing Record 47 of Set 6 | iquique
# Processing Record 48 of Set 6 | lata
# Processing Record 49 of Set 6 | hobyo
# Processing Record 50 of Set 6 | hualmay
# Processing Record 1 of Set 7 | acaponeta
# Processing Record 2 of Set 7 | guicheng
# City not found. Skipping...
# Processing Record 3 of Set 7 | milkovo
# Processing Record 4 of Set 7 | safford
# Processing Record 5 of Set 7 | souillac
# Processing Record 6 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 7 | kodinsk
# Processing Record 8 of Set 7 | kabompo
# Processing Record 9 of Set 7 | belaya gora
# Processing Record 10 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 7 | taraza
# Processing Record 12 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 7 | ostrovnoy
# Processing Record 14 of Set 7 | lokomotivnyy
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | weligama
# Processing Record 18 of Set 7 | slave lake
# Processing Record 19 of Set 7 | airai
# Processing Record 20 of Set 7 | moerai
# Processing Record 21 of Set 7 | tefe
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | makokou
# Processing Record 24 of Set 7 | avera
# Processing Record 25 of Set 7 | nishihara
# Processing Record 26 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 7 | santa maria
# Processing Record 28 of Set 7 | colonelganj
# Processing Record 29 of Set 7 | fez
# Processing Record 30 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 7 | general roca
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | ambon
# Processing Record 34 of Set 7 | nouadhibou
# Processing Record 35 of Set 7 | nome
# Processing Record 36 of Set 7 | castro
# Processing Record 37 of Set 7 | sawasawa
# City not found. Skipping...
# Processing Record 38 of Set 7 | florence
# Processing Record 39 of Set 7 | epernay
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | meadow lake
# Processing Record 42 of Set 7 | krasnoselkup
# Processing Record 43 of Set 7 | rafsanjan
# Processing Record 44 of Set 7 | pemberton
# Processing Record 45 of Set 7 | beyneu
# Processing Record 46 of Set 7 | khonsa
# Processing Record 47 of Set 7 | caborca
# Processing Record 48 of Set 7 | jinxiang
# Processing Record 49 of Set 7 | bilma
# Processing Record 50 of Set 7 | caledonia
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | hervey bay
# Processing Record 3 of Set 8 | scottsbluff
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | popondetta
# Processing Record 6 of Set 8 | mount isa
# Processing Record 7 of Set 8 | buala
# Processing Record 8 of Set 8 | taltal
# Processing Record 9 of Set 8 | kirksville
# Processing Record 10 of Set 8 | along
# Processing Record 11 of Set 8 | mount pleasant
# Processing Record 12 of Set 8 | imeni poliny osipenko
# Processing Record 13 of Set 8 | mednogorsk
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | hamilton
# Processing Record 16 of Set 8 | tuatapere
# Processing Record 17 of Set 8 | moose factory
# Processing Record 18 of Set 8 | sayyan
# Processing Record 19 of Set 8 | zheleznodorozhnyy
# Processing Record 20 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | solnechnyy
# Processing Record 22 of Set 8 | derzhavinsk
# Processing Record 23 of Set 8 | the valley
# Processing Record 24 of Set 8 | menongue
# Processing Record 25 of Set 8 | lebu
# Processing Record 26 of Set 8 | turukhansk
# Processing Record 27 of Set 8 | puerto madryn
# Processing Record 28 of Set 8 | nanortalik
# Processing Record 29 of Set 8 | lydenburg
# Processing Record 30 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | brae
# Processing Record 32 of Set 8 | waru
# Processing Record 33 of Set 8 | gat
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | griffith
# Processing Record 36 of Set 8 | pontes e lacerda
# Processing Record 37 of Set 8 | kapoeta
# Processing Record 38 of Set 8 | sombrerete
# Processing Record 39 of Set 8 | lambarene
# Processing Record 40 of Set 8 | vardo
# Processing Record 41 of Set 8 | shenjiamen
# Processing Record 42 of Set 8 | egvekinot
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | lucapa
# Processing Record 48 of Set 8 | porto belo
# Processing Record 49 of Set 8 | bowen
# Processing Record 50 of Set 8 | namtsy
# Processing Record 1 of Set 9 | spring hill
# Processing Record 2 of Set 9 | xuanhua
# Processing Record 3 of Set 9 | lagoa
# Processing Record 4 of Set 9 | haga
# Processing Record 5 of Set 9 | kenora
# Processing Record 6 of Set 9 | richards bay
# Processing Record 7 of Set 9 | altay
# Processing Record 8 of Set 9 | la vega
# Processing Record 9 of Set 9 | eyl
# Processing Record 10 of Set 9 | ascheberg
# Processing Record 11 of Set 9 | codrington
# Processing Record 12 of Set 9 | gobabis
# Processing Record 13 of Set 9 | kupang
# Processing Record 14 of Set 9 | luzhou
# Processing Record 15 of Set 9 | ajdabiya
# Processing Record 16 of Set 9 | bandiagara
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | sault sainte marie
# Processing Record 19 of Set 9 | great yarmouth
# Processing Record 20 of Set 9 | nelson bay
# Processing Record 21 of Set 9 | verkh-usugli
# Processing Record 22 of Set 9 | bairiki
# Processing Record 23 of Set 9 | benjamin constant
# Processing Record 24 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 25 of Set 9 | lajeado
# Processing Record 26 of Set 9 | bereznik
# Processing Record 27 of Set 9 | tucurui
# Processing Record 28 of Set 9 | balila
# Processing Record 29 of Set 9 | niimi
# Processing Record 30 of Set 9 | meulaboh
# Processing Record 31 of Set 9 | amfissa
# Processing Record 32 of Set 9 | takab
# Processing Record 33 of Set 9 | machacamarca
# Processing Record 34 of Set 9 | hofn
# Processing Record 35 of Set 9 | dunedin
# Processing Record 36 of Set 9 | kuryk
# Processing Record 37 of Set 9 | hirson
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 40 of Set 9 | polson
# Processing Record 41 of Set 9 | copiapo
# Processing Record 42 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 9 | laguna
# Processing Record 44 of Set 9 | homer
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | saint anthony
# Processing Record 47 of Set 9 | wynyard
# Processing Record 48 of Set 9 | cayenne
# Processing Record 49 of Set 9 | hansi
# Processing Record 50 of Set 9 | talaya
# Processing Record 1 of Set 10 | vila
# Processing Record 2 of Set 10 | iwanai
# Processing Record 3 of Set 10 | gold coast
# Processing Record 4 of Set 10 | marshfield
# Processing Record 5 of Set 10 | namatanai
# Processing Record 6 of Set 10 | channel-port aux basques
# Processing Record 7 of Set 10 | viedma
# Processing Record 8 of Set 10 | nova olinda do norte
# Processing Record 9 of Set 10 | orissaare
# Processing Record 10 of Set 10 | san rafael
# Processing Record 11 of Set 10 | waipawa
# Processing Record 12 of Set 10 | fayaoue
# Processing Record 13 of Set 10 | middleton
# Processing Record 14 of Set 10 | novikovo
# Processing Record 15 of Set 10 | tezu
# Processing Record 16 of Set 10 | lanigan
# Processing Record 17 of Set 10 | poum
# Processing Record 18 of Set 10 | sernur
# Processing Record 19 of Set 10 | batemans bay
# Processing Record 20 of Set 10 | lompoc
# Processing Record 21 of Set 10 | yumen
# Processing Record 22 of Set 10 | mabilo
# City not found. Skipping...
# Processing Record 23 of Set 10 | norton
# Processing Record 24 of Set 10 | nalut
# Processing Record 25 of Set 10 | willmar
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | hongjiang
# Processing Record 28 of Set 10 | fonte boa
# Processing Record 29 of Set 10 | harer
# Processing Record 30 of Set 10 | ahipara
# Processing Record 31 of Set 10 | sandy bay
# Processing Record 32 of Set 10 | luganville
# Processing Record 33 of Set 10 | manokwari
# Processing Record 34 of Set 10 | portland
# Processing Record 35 of Set 10 | patterson
# Processing Record 36 of Set 10 | waddan
# Processing Record 37 of Set 10 | baghdad
# Processing Record 38 of Set 10 | arkadelphia
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | walvis bay
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | dharan
# Processing Record 43 of Set 10 | ilhabela
# Processing Record 44 of Set 10 | gotsu
# Processing Record 45 of Set 10 | san luis
# Processing Record 46 of Set 10 | noyabrsk
# Processing Record 47 of Set 10 | beian
# Processing Record 48 of Set 10 | radford
# Processing Record 49 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 10 | eirunepe
# Processing Record 1 of Set 11 | dinan
# Processing Record 2 of Set 11 | galveston
# Processing Record 3 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | magadi
# Processing Record 5 of Set 11 | qostanay
# Processing Record 6 of Set 11 | bud
# Processing Record 7 of Set 11 | cerritos
# Processing Record 8 of Set 11 | hue
# Processing Record 9 of Set 11 | zapolyarnyy
# Processing Record 10 of Set 11 | rio gallegos
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | totskoye
# Processing Record 13 of Set 11 | yar-sale
# Processing Record 14 of Set 11 | jalingo
# Processing Record 15 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 16 of Set 11 | maniitsoq
# Processing Record 17 of Set 11 | mariestad
# Processing Record 18 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 11 | new plymouth
# Processing Record 20 of Set 11 | bongouanou
# Processing Record 21 of Set 11 | karabudakhkent
# Processing Record 22 of Set 11 | chippewa falls
# Processing Record 23 of Set 11 | tucumcari
# Processing Record 24 of Set 11 | curup
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | kangaatsiaq
# Processing Record 27 of Set 11 | pak phanang
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | juneau
# Processing Record 30 of Set 11 | bereda
# Processing Record 31 of Set 11 | ornskoldsvik
# Processing Record 32 of Set 11 | san clemente
# Processing Record 33 of Set 11 | bosaso
# Processing Record 34 of Set 11 | oum hadjer
# Processing Record 35 of Set 11 | zhaotong
# Processing Record 36 of Set 11 | sitka
# Processing Record 37 of Set 11 | port lincoln
# Processing Record 38 of Set 11 | araouane
# Processing Record 39 of Set 11 | great falls
# Processing Record 40 of Set 11 | presidencia roque saenz pena
# Processing Record 41 of Set 11 | alyangula
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | saint pete beach
# Processing Record 44 of Set 11 | diamantino
# Processing Record 45 of Set 11 | butte
# Processing Record 46 of Set 11 | gamba
# Processing Record 47 of Set 11 | baruun-urt
# Processing Record 48 of Set 11 | pangody
# Processing Record 49 of Set 11 | antalaha
# Processing Record 50 of Set 11 | uruguaiana
# Processing Record 1 of Set 12 | ankpa
# Processing Record 2 of Set 12 | saldanha
# Processing Record 3 of Set 12 | shirokiy
# Processing Record 4 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 12 | xai-xai
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 7 of Set 12 | chilca
# Processing Record 8 of Set 12 | san jose
# Processing Record 9 of Set 12 | hailey
# Processing Record 10 of Set 12 | cabra
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | careiro da varzea
# Processing Record 13 of Set 12 | moyale
# Processing Record 14 of Set 12 | toyooka
# Processing Record 15 of Set 12 | byron bay
# Processing Record 16 of Set 12 | kenai
# Processing Record 17 of Set 12 | beloslav
# Processing Record 18 of Set 12 | graham
# Processing Record 19 of Set 12 | areia branca
# Processing Record 20 of Set 12 | sioux lookout
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | venice
# Processing Record 23 of Set 12 | teahupoo
# Processing Record 24 of Set 12 | huarmey
# Processing Record 25 of Set 12 | mecca
# Processing Record 26 of Set 12 | dovolnoye
# Processing Record 27 of Set 12 | lima
# Processing Record 28 of Set 12 | sompeta
# Processing Record 29 of Set 12 | istok
# Processing Record 30 of Set 12 | perth
# Processing Record 31 of Set 12 | anse-bertrand
# Processing Record 32 of Set 12 | batagay
# Processing Record 33 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 34 of Set 12 | kholmy
# Processing Record 35 of Set 12 | pandan
# Processing Record 36 of Set 12 | benguela
# Processing Record 37 of Set 12 | rongcheng
# Processing Record 38 of Set 12 | strezhevoy
# Processing Record 39 of Set 12 | ponta delgada
# Processing Record 40 of Set 12 | mayumba
# Processing Record 41 of Set 12 | karratha
# Processing Record 42 of Set 12 | wukari
# Processing Record 43 of Set 12 | kautokeino
# Processing Record 44 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 12 | banyo
# Processing Record 46 of Set 12 | yenisea
# City not found. Skipping...
# Processing Record 47 of Set 12 | hokitika
# Processing Record 48 of Set 12 | khani
# Processing Record 49 of Set 12 | bichena
# Processing Record 50 of Set 12 | mingaora
# Processing Record 1 of Set 13 | alice springs
# Processing Record 2 of Set 13 | ust-maya
# Processing Record 3 of Set 13 | marrakesh
# Processing Record 4 of Set 13 | itaituba
# Processing Record 5 of Set 13 | sukumo
# Processing Record 6 of Set 13 | cravo norte
# Processing Record 7 of Set 13 | zirandaro
# Processing Record 8 of Set 13 | hoquiam
# Processing Record 9 of Set 13 | xining
# Processing Record 10 of Set 13 | chapais
# Processing Record 11 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 13 | port macquarie
# Processing Record 13 of Set 13 | praia da vitoria
# Processing Record 14 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 13 | zyryanka
# Processing Record 16 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 17 of Set 13 | sapulpa
# Processing Record 18 of Set 13 | pauini
# Processing Record 19 of Set 13 | dembi dolo
# Processing Record 20 of Set 13 | vaitape
# Processing Record 21 of Set 13 | dabat
# Processing Record 22 of Set 13 | kysyl-syr
# Processing Record 23 of Set 13 | topolobampo
# Processing Record 24 of Set 13 | tucuman
# Processing Record 25 of Set 13 | penticton
# Processing Record 26 of Set 13 | vasilsursk
# Processing Record 27 of Set 13 | mohpa
# Processing Record 28 of Set 13 | stepnyak
# Processing Record 29 of Set 13 | duz
# City not found. Skipping...
# Processing Record 30 of Set 13 | luleburgaz
# Processing Record 31 of Set 13 | rawah
# Processing Record 32 of Set 13 | jiuquan
# Processing Record 33 of Set 13 | kyabram
# Processing Record 34 of Set 13 | rosario
# Processing Record 35 of Set 13 | quatre cocos
# Processing Record 36 of Set 13 | cairns
# Processing Record 37 of Set 13 | rantauprapat
# Processing Record 38 of Set 13 | lundazi
# Processing Record 39 of Set 13 | sulangan
# Processing Record 40 of Set 13 | urumqi
# Processing Record 41 of Set 13 | narok
# Processing Record 42 of Set 13 | flinders
# Processing Record 43 of Set 13 | oistins
# Processing Record 44 of Set 13 | varberg
# Processing Record 45 of Set 13 | finschhafen
# Processing Record 46 of Set 13 | champerico
# Processing Record 47 of Set 13 | palana
# Processing Record 48 of Set 13 | kruisfontein
# Processing Record 49 of Set 13 | cruden bay
# City not found. Skipping...
# Processing Record 50 of Set 13 | bandarbeyla
# Processing Record 1 of Set 14 | nanakuli
# Processing Record 2 of Set 14 | ambanja
# Processing Record 3 of Set 14 | freeport
# Processing Record 4 of Set 14 | moscow
# Processing Record 5 of Set 14 | lufilufi
# Processing Record 6 of Set 14 | fairbanks
# Processing Record 7 of Set 14 | grindavik
# Processing Record 8 of Set 14 | nouakchott
# Processing Record 9 of Set 14 | grand gaube
# Processing Record 10 of Set 14 | laje
# Processing Record 11 of Set 14 | hohhot
# Processing Record 12 of Set 14 | emerald
# Processing Record 13 of Set 14 | raga
# Processing Record 14 of Set 14 | tsuyama
# Processing Record 15 of Set 14 | lovozero
# Processing Record 16 of Set 14 | odweyne
# Processing Record 17 of Set 14 | kargasok
# Processing Record 18 of Set 14 | fort morgan
# Processing Record 19 of Set 14 | ayagoz
# Processing Record 20 of Set 14 | kholtoson
# Processing Record 21 of Set 14 | taraz
# Processing Record 22 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 14 | maarianhamina
# Processing Record 24 of Set 14 | kemijarvi
# Processing Record 25 of Set 14 | vung tau
# Processing Record 26 of Set 14 | lumphat
# Processing Record 27 of Set 14 | dongsheng
# Processing Record 28 of Set 14 | saint marys
# Processing Record 29 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 14 | sinnamary
# Processing Record 31 of Set 14 | comodoro rivadavia
# Processing Record 32 of Set 14 | samarai
# Processing Record 33 of Set 14 | marapanim
# Processing Record 34 of Set 14 | oranjestad
# Processing Record 35 of Set 14 | novobeysugskaya
# Processing Record 36 of Set 14 | maceio
# Processing Record 37 of Set 14 | santa cruz de tenerife
# Processing Record 38 of Set 14 | saint simons
# Processing Record 39 of Set 14 | wangjing
# Processing Record 40 of Set 14 | la libertad
# Processing Record 41 of Set 14 | conchal
# Processing Record 42 of Set 14 | vestmanna
# Processing Record 43 of Set 14 | kloulklubed
# Processing Record 44 of Set 14 | qandala
# Processing Record 45 of Set 14 | hay river
# Processing Record 46 of Set 14 | mazatlan
# Processing Record 47 of Set 14 | tautira
# Processing Record 48 of Set 14 | ortona
# Processing Record 49 of Set 14 | methoni
# Processing Record 50 of Set 14 | medina del campo
# Processing Record 1 of Set 15 | acapulco
# Processing Record 2 of Set 15 | moron
# Processing Record 3 of Set 15 | paris
# Processing Record 4 of Set 15 | kpandae
# Processing Record 5 of Set 15 | yenangyaung
# Processing Record 6 of Set 15 | heihe
# Processing Record 7 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 15 | batagay-alyta
# Processing Record 9 of Set 15 | shelton
# Processing Record 10 of Set 15 | prince rupert
# Processing Record 11 of Set 15 | vostok
# Processing Record 12 of Set 15 | vysokogornyy
# Processing Record 13 of Set 15 | davila
# Processing Record 14 of Set 15 | paidha
# Processing Record 15 of Set 15 | alcudia
# Processing Record 16 of Set 15 | trairi
# Processing Record 17 of Set 15 | sorland
# Processing Record 18 of Set 15 | hays
# Processing Record 19 of Set 15 | kasamwa
# Processing Record 20 of Set 15 | cacoal
# Processing Record 21 of Set 15 | mayo
# Processing Record 22 of Set 15 | libato
# Processing Record 23 of Set 15 | moree
# Processing Record 24 of Set 15 | ciudad bolivar
# Processing Record 25 of Set 15 | kuopio
# Processing Record 26 of Set 15 | encheng
# Processing Record 27 of Set 15 | caravelas
# Processing Record 28 of Set 15 | simbahan
# Processing Record 29 of Set 15 | leeuwarden
# Processing Record 30 of Set 15 | josefina
# Processing Record 31 of Set 15 | abnub
# Processing Record 32 of Set 15 | tonekabon
# Processing Record 33 of Set 15 | ewa beach
# Processing Record 34 of Set 15 | saint-francois
# Processing Record 35 of Set 15 | florianopolis
# Processing Record 36 of Set 15 | kondinskoye
# Processing Record 37 of Set 15 | stara synyava
# Processing Record 38 of Set 15 | mana
# Processing Record 39 of Set 15 | enshi
# Processing Record 40 of Set 15 | talas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#requests.get(city_url).json()["weather"][0]["description"]

# %%
# Checking length to ensure records exist
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     57.20        41          20
# 1         Nazare      BR -13.0350  -39.0144     94.80        39          93
# 2       Tasiilaq      GL  65.6145  -37.6368     32.00        93          75
# 3      Carnarvon      AU -24.8667  113.6333     80.60       100          40
# 4        Rikitea      PF -23.1203 -134.9692     77.47        75         100
# 5          Bluff      NZ -46.6000  168.3333     53.92        85          19
# 6          Vaini      TO -21.2000 -175.2000     73.40       100          90
# 7           Asau      RO  46.4333   26.4000     30.00        76         100
# 8         Hobart      AU -42.8794  147.3294     57.99        82          75
# 9  Traverse City      US  44.7631  -85.6206     12.20        79          90
#
#    Wind Speed       Description
# 0       19.57        few clouds
# 1        8.21   overcast clouds
# 2       44.87              snow
# 3       11.50  scattered clouds
# 4       13.15   overcast clouds
# 5        3.31        few clouds
# 6       11.50   overcast clouds
# 7        3.20   overcast clouds
# 8        6.91     broken clouds
# 9       10.36              snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
